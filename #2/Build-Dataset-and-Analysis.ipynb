# %%
import pandas as pd
import numpy as np
import random
from IPython.display import display, HTML
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("dataset.csv")
display(dataset.info())
display(dataset.head(10))

# %%
dataset = pd.read_csv("dataset.csv")
jobs = [
    "Engineer",
    "Teacher",
    "Doctor",
    "Waiter",
    "Manager",
    "Accountant",
    "Lawyer"
]

jobs_income = [
    [40000,60000],
    [20000,35000],
    [60000,100000],
    [10000,20000],
    [40000,60000],
    [40000,60000],
    [30000,80000],
]

city = [
    "Viseu",
    "Coimbra",
    "Porto",
    "Aveiro",
    "Lisboa",
    "Braga",
    "Faro",
    "Castelo Branco",
]

signs = [
    "Aquarius",
    "Pisces",
    "Aries",
    "Taurus",
    "Gemini",
    "Cancer",
    "Leo",
    "Virgo",
    "Libra",
    "Scorpio",
    "Sagittarius",
    "Capricorn"
]

def return_income(job):
    incomes = jobs_income[jobs.index(job)]
    return random.randint(incomes[0], incomes[1])
    

def generate_date_of_birth(yo):
    yyyy = 2020-yo
    mm = random.randint(1, 12)
    dd = random.randint(1, 30)
    return "%02d-%02d-%4d" % (dd,mm,yyyy)

    
dataset["job"] = np.array([np.random.choice(jobs,1)[0] for i in range(dataset.shape[0])])
dataset["income_per_year"] = list(map(lambda x: return_income(x),dataset["job"]))
dataset["age"] = [random.randint(23, 60) for i in range(dataset.shape[0])]
dataset["number_kids"] = [random.randint(0, 4) for i in range(dataset.shape[0])]
dataset["city"] = [random.sample(city, 1)[0] for i in range(dataset.shape[0])]
dataset["signs"] = [random.sample(signs, 1)[0] for i in range(dataset.shape[0])]
dataset = dataset.drop(columns=["address"])

dataset.to_csv("dataset_complete.csv")

# %%
dataset = pd.read_csv("dataset_final.csv")
dataset
# Out:
#                       name                        email  gender  \
# 0              Glenn Rowan           growan0@flickr.com    Male
# 1    Cristiano Scartifield    cscartifield1@comcast.net    Male
# 2             Marna Heaphy        mheaphy2@amazon.co.uk  Female
# 3               Saul Avery           savery3@boston.com    Male
# 4            Denver Batter           dbatter4@intel.com    Male
# ..                     ...                          ...     ...
# 995        Johanna Demange  jdemangern@miitbeian.gov.cn  Female
# 996         Illa McRannell     imcrannellro@skyrock.com  Female
# 997           Tamiko Sheer          tsheerrp@dyndns.org  Female
# 998     Timothea Dawidsohn      tdawidsohnrq@rambler.ru  Female
# 999            Herbie Pryn            hprynrr@naver.com    Male
#
#           ip_address         phone         job          ssn  \
# 0    112.148.196.224  813-696-5199      Waiter  267-29-8707
# 1      44.106.121.91  933-931-1180  Accountant  689-09-5993
# 2    155.104.214.101  613-523-2910     Teacher  610-07-3584
# 3      59.221.62.108  867-466-4882  Accountant  451-59-2254
# 4     124.84.102.205  748-665-8473     Teacher  701-07-1647
# ..               ...           ...         ...          ...
# 995    40.140.178.64  493-278-6885     Manager  283-33-4127
# 996  184.206.234.182  294-968-4264     Teacher  815-23-5380
# 997    15.177.44.163  813-986-1643      Doctor  128-74-1887
# 998    69.214.190.99  122-433-0001     Teacher  750-05-7543
# 999  128.161.226.103  497-493-5337     Manager  339-34-9097
#
#               credit_card  income_per_year  age  number_kids            city  \
# 0        5602241452639272            19711   29            2  Castelo Branco
# 1        3579239618421746            50917   30            4           Viseu
# 2        3571615590907745            23226   35            0           Viseu
# 3         201668308913590            57054   57            1          Lisboa
# 4    4,9050683323544E+017            24859   45            2          Aveiro
# ..                    ...              ...  ...          ...             ...
# 995       337941922780803            44856   30            4          Lisboa
# 996      5100179444162549            28781   60            2           Viseu
# 997      5362288664972231            78298   37            2          Lisboa
# 998      3528921899274629            23813   56            2           Viseu
# 999      6331100261100585            43782   43            1           Porto
#
#            signs
# 0        Scorpio
# 1        Scorpio
# 2         Cancer
# 3    Sagittarius
# 4       Aquarius
# ..           ...
# 995     Aquarius
# 996  Sagittarius
# 997  Sagittarius
# 998        Virgo
# 999        Libra
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## Analysis

# %%
def analysis(name_file):
    dataset = pd.read_csv(name_file)
    display(HTML('<h4>Analysis by gender</h4'))
    display(dataset.groupby("gender").mean()[["income_per_year","number_kids"]])
    display(HTML('<h4>Analysis by city</h4'))
    display(dataset.groupby("city").mean()[["income_per_year","number_kids"]])
    display(HTML('<h4>Analysis by age</h4'))
    display(dataset.groupby("age").mean()[["income_per_year","number_kids"]])
    display(HTML('<h4>Analysis by job</h4'))
    display(dataset.groupby("job").mean()[["income_per_year","number_kids"]])
    display(HTML('<h4>Analysis by signs</h4'))
    display(dataset.groupby("signs").mean()[["income_per_year","number_kids"]])

# %%
display(HTML('<h1>Original Dataset</h1>'))
display(HTML('<h2>Analysis</h2>'))
analysis("dataset_final.csv")
display(HTML('<h3>Distinction and Separation</h3>'))
display(pd.read_csv("original_sep.csv"))
display(HTML('<h3>Risk</h3>'))
display(pd.read_csv("original_risk.csv"))
# Out:
# <h1>Original Dataset</h1>
# <h2>Analysis</h2>
# <h4>Analysis by gender</h4
#         income_per_year  number_kids
# gender
# Female     46230.110220      2.02004
# Male       46998.105788      1.89022
# <h4>Analysis by city</h4
#                 income_per_year  number_kids
# city
# Aveiro             50495.992593     2.103704
# Braga              45636.715517     1.965517
# Castelo Branco     47734.728682     1.984496
# Coimbra            48377.017241     1.965517
# Faro               47572.396396     1.891892
# Lisboa             46197.371901     1.983471
# Porto              43783.720000     1.768000
# Viseu              43477.285714     1.959184
# <h4>Analysis by age</h4
#      income_per_year  number_kids
# age
# 23      50560.900000     1.850000
# 24      47311.242424     1.909091
# 25      51602.483871     1.677419
# 26      54566.285714     2.238095
# 27      39126.045455     1.863636
# 28      41129.684211     2.052632
# 29      47792.968750     2.000000
# 30      42328.960000     2.440000
# 31      36774.961538     1.615385
# 32      50397.382353     1.882353
# 33      47980.000000     2.235294
# 34      56580.277778     1.555556
# 35      46414.680000     2.080000
# 36      41603.200000     1.680000
# 37      50578.333333     2.000000
# 38      48759.714286     2.357143
# 39      39590.578947     2.000000
# 40      55183.111111     1.388889
# 41      49715.333333     2.233333
# 42      46109.742857     2.114286
# 43      47043.000000     1.931034
# 44      43582.954545     2.227273
# 45      47463.421053     2.473684
# 46      46249.833333     1.933333
# 47      49076.400000     1.866667
# 48      45500.000000     1.433333
# 49      49735.880000     1.840000
# 50      45680.444444     2.037037
# 51      43346.448276     1.689655
# 52      43579.454545     2.136364
# 53      45500.038462     1.730769
# 54      51984.969697     1.787879
# 55      44640.920000     2.120000
# 56      40173.035714     2.107143
# 57      42264.935484     1.774194
# 58      47649.861111     1.805556
# 59      47712.346154     1.692308
# 60      46152.840000     2.600000
# <h4>Analysis by job</h4
#             income_per_year  number_kids
# job
# Accountant     50019.400000     1.776923
# Doctor         80684.625000     1.947368
# Engineer       50370.781250     1.968750
# Lawyer         53983.263889     2.131944
# Manager        49782.144828     2.027586
# Teacher        27477.147651     1.885906
# Waiter         15228.519737     1.934211
# <h4>Analysis by signs</h4
#              income_per_year  number_kids
# signs
# Aquarius        48025.326087     1.793478
# Aries           47358.603960     1.881188
# Cancer          47310.526316     2.039474
# Capricorn       45997.771429     2.014286
# Gemini          46777.067568     2.162162
# Leo             46765.565789     2.289474
# Libra           43984.583333     1.802083
# Pisces          45042.026667     2.013333
# Sagittarius     48642.576471     1.941176
# Scorpio         46077.930233     1.837209
# Taurus          46456.712329     1.821918
# Virgo           46800.666667     1.979167
# <h3>Distinction and Separation</h3>
#                  Quasi-identifier Distinction Separation
# 0                          gender        0.2%  50.04985%
# 1                             job        0.7%  85.74034%
# 2                            city        0.8%  87.49009%
# 3                           signs        1.2%  91.63163%
# 4                             age        3.8%  97.35816%
# 5                     gender, job        1.4%  92.86927%
# 6                    gender, city        1.6%  93.75716%
# 7                   gender, signs        2.4%  95.84184%
# 8                       job, city        5.6%   98.1952%
# 9                     gender, age        7.6%  98.68529%
# 10                     job, signs        8.4%  98.81642%
# 11                    city, signs        9.6%  98.93734%
# 12                       job, age      26,00%  99.62763%
# 13                      age, city       29.3%  99.65926%
# 14                     age, signs       41.3%  99.79139%
# 15              gender, job, city       11.2%   99.1017%
# 16             gender, job, signs       16.8%  99.40961%
# 17            gender, city, signs       19.2%  99.47287%
# 18               gender, job, age       45.1%  99.81602%
# 19              gender, age, city      48,00%  99.82823%
# 20               job, city, signs       51.4%  99.84104%
# 21             gender, age, signs       62.1%   99.9005%
# 22                 job, age, city       79.3%  99.94955%
# 23               age, city, signs       86.4%  99.97077%
# 24                job, age, signs       87.5%  99.97337%
# 25       gender, job, city, signs       69.5%  99.92192%
# 26         gender, job, age, city       88.8%  99.97598%
# 27       gender, age, city, signs       92.5%  99.98478%
# 28        gender, job, age, signs      95,00%  99.98999%
# 29          job, age, city, signs       97.8%   99.9954%
# 30  gender, job, age, city, signs       99.4%   99.9988%
# <h3>Risk</h3>
#                              Measure                      Value [%]
# 0             Lowest prosecutor risk                         50,00%
# 1    Records affected by lowest risk                           1.2%
# 2            Average prosecutor risk                          99.4%
# 3            Highest prosecutor risk                        100,00%
# 4   Records affected by highest risk                          98.8%
# 5          Estimated prosecutor risk                        100,00%
# 6          Estimated journalist risk                        100,00%
# 7            Estimated marketer risk                          99.4%
# 8                     Sample uniques                          98.8%
# 9                 Population uniques                       97.6144%
# 10                  Population model                         ZAYATZ
# 11                 Quasi-identifiers  age, city, gender, job, signs

# %% [markdown]
# # Post Analysis

# %%
display(HTML('<h1>Original Dataset</h1>'))
display(HTML('<h2>Analysis</h2>'))
analysis("out_1.csv")
display(HTML('<h3>Distinction and Separation</h3>'))
display(pd.read_csv("out1_sep.csv"))
display(HTML('<h3>Risk</h3>'))
display(pd.read_csv("out1_risk.csv"))
# Out:
# <h1>Original Dataset</h1>
# <h2>Analysis</h2>
# <h4>Analysis by gender</h4
#         income_per_year  number_kids
# gender
# *          51511.437500     2.093750
# Female     45922.613497     1.997955
# Male       46994.471816     1.901879
# <h4>Analysis by city</h4
#                                           income_per_year  number_kids
# city
# *                                            51511.437500     2.093750
# {Aveiro, Braga, Castelo Branco, Coimbra}     47913.719828     2.002155
# {Faro, Lisboa, Porto, Viseu}                 45108.222222     1.902778
# <h4>Analysis by age</h4
#           income_per_year  number_kids
# age
# *            51511.437500     2.093750
# [23, 38[     46651.083770     1.913613
# [38, 53[     46998.856369     1.983740
# [53, 61[     45176.119816     1.958525
# <h4>Analysis by job</h4
#                                         income_per_year  number_kids
# job
# *                                          51511.437500     2.093750
# {Accountant, Doctor, Engineer, Lawyer}     59358.379439     1.940187
# {Manager, Teacher, Waiter}                 30507.568129     1.963048
# <h4>Analysis by signs</h4
#                                        income_per_year  number_kids
# signs
# *                                         51511.437500     2.093750
# {Aquarius, Aries, Cancer, Capricorn}      47100.199377     1.925234
# {Gemini, Leo, Libra, Pisces}              45027.945338     2.016077
# {Sagittarius, Scorpio, Taurus, Virgo}     47153.735119     1.913690
# <h3>Distinction and Separation</h3>
#                  Quasi-identifier Distinction Separation
# 0                             job    0.20661%  49.49597%
# 1                            city    0.20661%  49.96624%
# 2                          gender    0.20661%  50.04636%
# 3                             age    0.30992%  64.93735%
# 4                           signs    0.30992%  66.70178%
# 5                       job, city    0.41322%  74.70985%
# 6                     gender, job    0.41322%  74.78634%
# 7                    gender, city    0.41322%  75.00128%
# 8                        job, age    0.61983%   82.1876%
# 9                     gender, age    0.61983%  82.30362%
# 10                      age, city    0.61983%  82.49058%
# 11                     job, signs    0.61983%  83.14011%
# 12                  gender, signs    0.61983%  83.36082%
# 13                    city, signs    0.61983%  83.36852%
# 14                     age, signs    0.92975%  88.22207%
# 15              gender, job, city    0.82645%  87.38366%
# 16               gender, job, age    1.23967%  91.03002%
# 17                 job, age, city    1.23967%  91.07254%
# 18              gender, age, city    1.23967%  91.17083%
# 19               job, city, signs    1.23967%  91.57679%
# 20             gender, job, signs    1.23967%  91.58683%
# 21            gender, city, signs    1.23967%   91.6458%
# 22                job, age, signs     1.8595%  93.98305%
# 23             gender, age, signs     1.8595%  94.03732%
# 24               age, city, signs     1.8595%  94.11616%
# 25         gender, job, age, city    2.47934%  95.50753%
# 26       gender, job, city, signs    2.47934%  95.76713%
# 27        gender, job, age, signs    3.71901%  96.95189%
# 28          job, age, city, signs    3.71901%  96.96407%
# 29       gender, age, city, signs    3.71901%  97.02112%
# 30  gender, job, age, city, signs    7.02479%  98.44881%
# <h3>Risk</h3>
#                              Measure                      Value [%]
# 0             Lowest prosecutor risk                       3.84615%
# 1    Records affected by lowest risk                       2.68595%
# 2            Average prosecutor risk                       7.02479%
# 3            Highest prosecutor risk                         20,00%
# 4   Records affected by highest risk                       0.51653%
# 5          Estimated prosecutor risk                         20,00%
# 6          Estimated journalist risk                         20,00%
# 7            Estimated marketer risk                       7.02479%
# 8                     Sample uniques                          0,00%
# 9                 Population uniques                          0,00%
# 10                  Population model                         DANKAR
# 11                 Quasi-identifiers  age, city, gender, job, signs

# %%
analysis("out_2.csv")
# Out:
# <h3>Analysis by gender</h3>
#         income_per_year  number_kids
# gender
# Female     46230.110220      2.02004
# Male       46998.105788      1.89022
# <h3>Analysis by city</h3>
#                                                     income_per_year  \
# city
# {Aveiro, Braga, Castelo Branco, Coimbra, Faro, ...        46614.876
#
#                                                     number_kids
# city
# {Aveiro, Braga, Castelo Branco, Coimbra, Faro, ...        1.955
# <h3>Analysis by age</h3>
#           income_per_year  number_kids
# age
# [23, 38[     47023.931122     1.943878
# [38, 53[     46619.502646     1.978836
# [53, 61[     45910.100000     1.934783
# <h3>Analysis by job</h3>
#                                         income_per_year  number_kids
# job
# {Accountant, Doctor, Engineer, Lawyer}     59544.467509     1.960289
# {Manager, Teacher, Waiter}                 30554.352018     1.948430
# <h3>Analysis by signs</h3>
#                                        income_per_year  number_kids
# signs
# {Aquarius, Aries, Cancer, Capricorn}      47247.766962     1.920354
# {Gemini, Leo, Libra, Pisces}              45533.825545     2.049844
# {Sagittarius, Scorpio, Taurus, Virgo}     47004.485294     1.900000

# %% [markdown]
# ## Separation & Distinction

# %%
display(HTML('<h3>Original</h3>'))
display(pd.read_csv("original_sep.csv"))
display(pd.read_csv("original_risk.csv"))
display(HTML('<img src = "original_risk.png">'))
# Out:
# <h3>Original</h3>
#                  Quasi-identifier Distinction Separation
# 0                          gender        0.2%  50.04985%
# 1                             job        0.7%  85.74034%
# 2                            city        0.8%  87.49009%
# 3                           signs        1.2%  91.63163%
# 4                             age        3.8%  97.35816%
# 5                     gender, job        1.4%  92.86927%
# 6                    gender, city        1.6%  93.75716%
# 7                   gender, signs        2.4%  95.84184%
# 8                       job, city        5.6%   98.1952%
# 9                     gender, age        7.6%  98.68529%
# 10                     job, signs        8.4%  98.81642%
# 11                    city, signs        9.6%  98.93734%
# 12                       job, age      26,00%  99.62763%
# 13                      age, city       29.3%  99.65926%
# 14                     age, signs       41.3%  99.79139%
# 15              gender, job, city       11.2%   99.1017%
# 16             gender, job, signs       16.8%  99.40961%
# 17            gender, city, signs       19.2%  99.47287%
# 18               gender, job, age       45.1%  99.81602%
# 19              gender, age, city      48,00%  99.82823%
# 20               job, city, signs       51.4%  99.84104%
# 21             gender, age, signs       62.1%   99.9005%
# 22                 job, age, city       79.3%  99.94955%
# 23               age, city, signs       86.4%  99.97077%
# 24                job, age, signs       87.5%  99.97337%
# 25       gender, job, city, signs       69.5%  99.92192%
# 26         gender, job, age, city       88.8%  99.97598%
# 27       gender, age, city, signs       92.5%  99.98478%
# 28        gender, job, age, signs      95,00%  99.98999%
# 29          job, age, city, signs       97.8%   99.9954%
# 30  gender, job, age, city, signs       99.4%   99.9988%
#                              Measure                      Value [%]
# 0             Lowest prosecutor risk                         50,00%
# 1    Records affected by lowest risk                           1.2%
# 2            Average prosecutor risk                          99.4%
# 3            Highest prosecutor risk                        100,00%
# 4   Records affected by highest risk                          98.8%
# 5          Estimated prosecutor risk                        100,00%
# 6          Estimated journalist risk                        100,00%
# 7            Estimated marketer risk                          99.4%
# 8                     Sample uniques                          98.8%
# 9                 Population uniques                       97.6144%
# 10                  Population model                         ZAYATZ
# 11                 Quasi-identifiers  age, city, gender, job, signs
# <img src = "original_risk.png">

# %%
display(HTML('<h3>Out 1</h3>'))
display(HTML('<h5>[Gender,job,age,city,signs] - [0,2,1,2,2]</h5>'))
print("income_per_year - Distinct-4-diversity")
print("number_kids - Distinct-4-diversity")
display(pd.read_csv("out1_sep.csv"))
display(pd.read_csv("out1_risk.csv"))
display(HTML('<img src = "out1_risk.png">'))
# Out:
# <h3>Out 1</h3>
# <h5>[Gender,job,age,city,signs] - [0,2,1,2,2]</h5>
# income_per_year - Distinct-4-diversity
# number_kids - Distinct-4-diversity
#                  Quasi-identifier Distinction Separation
# 0                             job    0.20661%  49.49597%
# 1                            city    0.20661%  49.96624%
# 2                          gender    0.20661%  50.04636%
# 3                             age    0.30992%  64.93735%
# 4                           signs    0.30992%  66.70178%
# 5                       job, city    0.41322%  74.70985%
# 6                     gender, job    0.41322%  74.78634%
# 7                    gender, city    0.41322%  75.00128%
# 8                        job, age    0.61983%   82.1876%
# 9                     gender, age    0.61983%  82.30362%
# 10                      age, city    0.61983%  82.49058%
# 11                     job, signs    0.61983%  83.14011%
# 12                  gender, signs    0.61983%  83.36082%
# 13                    city, signs    0.61983%  83.36852%
# 14                     age, signs    0.92975%  88.22207%
# 15              gender, job, city    0.82645%  87.38366%
# 16               gender, job, age    1.23967%  91.03002%
# 17                 job, age, city    1.23967%  91.07254%
# 18              gender, age, city    1.23967%  91.17083%
# 19               job, city, signs    1.23967%  91.57679%
# 20             gender, job, signs    1.23967%  91.58683%
# 21            gender, city, signs    1.23967%   91.6458%
# 22                job, age, signs     1.8595%  93.98305%
# 23             gender, age, signs     1.8595%  94.03732%
# 24               age, city, signs     1.8595%  94.11616%
# 25         gender, job, age, city    2.47934%  95.50753%
# 26       gender, job, city, signs    2.47934%  95.76713%
# 27        gender, job, age, signs    3.71901%  96.95189%
# 28          job, age, city, signs    3.71901%  96.96407%
# 29       gender, age, city, signs    3.71901%  97.02112%
# 30  gender, job, age, city, signs    7.02479%  98.44881%
#                              Measure                      Value [%]
# 0             Lowest prosecutor risk                       3.84615%
# 1    Records affected by lowest risk                       2.68595%
# 2            Average prosecutor risk                       7.02479%
# 3            Highest prosecutor risk                         20,00%
# 4   Records affected by highest risk                       0.51653%
# 5          Estimated prosecutor risk                         20,00%
# 6          Estimated journalist risk                         20,00%
# 7            Estimated marketer risk                       7.02479%
# 8                     Sample uniques                          0,00%
# 9                 Population uniques                          0,00%
# 10                  Population model                         DANKAR
# 11                 Quasi-identifiers  age, city, gender, job, signs
# <img src = "out1_risk.png">

# %%
display(HTML('<h3>Out 2</h3>'))
display(HTML('<h5>[Gender,job,age,city,signs] - [0,2,1,3,2]</h5>'))
print("income_per_year - Distinct-4-diversity")
print("number_kids - Distinct-2-diversity")
print("10-Anonymity")
display(pd.read_csv("out2_sep.csv"))
display(pd.read_csv("out2_risk.csv"))
display(HTML('<img src = "out2_risk.png">'))
# Out:
# <h3>Out 2</h3>
# <h5>[Gender,job,age,city,signs] - [0,2,1,3,2]</h5>
# income_per_year - Distinct-4-diversity
# number_kids - Distinct-2-diversity
# 10-Anonymity
#                  Quasi-identifier Distinction Separation
# 0                            city        0.1%      0,00%
# 1                             job        0.2%  49.46627%
# 2                          gender        0.2%  50.04985%
# 3                             age        0.3%  65.12032%
# 4                           signs        0.3%  66.71051%
# 5                       job, city        0.2%  49.46627%
# 6                    gender, city        0.2%  50.04985%
# 7                       age, city        0.3%  65.12032%
# 8                     city, signs        0.3%  66.71051%
# 9                     gender, job        0.4%  74.78218%
# 10                       job, age        0.6%  82.31471%
# 11                    gender, age        0.6%   82.5039%
# 12                     job, signs        0.6%  83.14454%
# 13                  gender, signs        0.6%   83.3958%
# 14                     age, signs        0.9%  88.36476%
# 15              gender, job, city        0.4%  74.78218%
# 16                 job, age, city        0.6%  82.31471%
# 17              gender, age, city        0.6%   82.5039%
# 18               job, city, signs        0.6%  83.14454%
# 19            gender, city, signs        0.6%   83.3958%
# 20               age, city, signs        0.9%  88.36476%
# 21               gender, job, age        1.2%  91.15015%
# 22             gender, job, signs        1.2%  91.61321%
# 23                job, age, signs        1.8%  94.07628%
# 24             gender, age, signs        1.8%  94.15716%
# 25         gender, job, age, city        1.2%  91.15015%
# 26       gender, job, city, signs        1.2%  91.61321%
# 27          job, age, city, signs        1.8%  94.07628%
# 28       gender, age, city, signs        1.8%  94.15716%
# 29        gender, job, age, signs        3.6%  97.03904%
# 30  gender, job, age, city, signs        3.6%  97.03904%
#                              Measure                      Value [%]
# 0             Lowest prosecutor risk                          2,00%
# 1    Records affected by lowest risk                          5,00%
# 2            Average prosecutor risk                           3.6%
# 3            Highest prosecutor risk                          6.25%
# 4   Records affected by highest risk                           1.6%
# 5          Estimated prosecutor risk                          6.25%
# 6          Estimated journalist risk                          6.25%
# 7            Estimated marketer risk                           3.6%
# 8                     Sample uniques                          0,00%
# 9                 Population uniques                          0,00%
# 10                  Population model                         DANKAR
# 11                 Quasi-identifiers  age, city, gender, job, signs
# <img src = "out2_risk.png">

# %% [markdown]
# ## Compare

# %%
original = list(map(lambda x: float(x[:-1].replace(",",".")) , pd.read_csv("original_sep.csv")["Distinction"].values))
o1 = list(map(lambda x: float(x[:-1].replace(",",".")) , pd.read_csv("out1_sep.csv")["Distinction"].values))
o2 = list(map(lambda x: float(x[:-1].replace(",",".")) , pd.read_csv("out2_sep.csv")["Distinction"].values))

# %%
label
# Out:
# array(['city', 'job', 'gender', 'age', 'signs', 'job, city',
#        'gender, city', 'age, city', 'city, signs', 'gender, job',
#        'job, age', 'gender, age', 'job, signs', 'gender, signs',
#        'age, signs', 'gender, job, city', 'job, age, city',
#        'gender, age, city', 'job, city, signs', 'gender, city, signs',
#        'age, city, signs', 'gender, job, age', 'gender, job, signs',
#        'job, age, signs', 'gender, age, signs', 'gender, job, age, city',
#        'gender, job, city, signs', 'job, age, city, signs',
#        'gender, age, city, signs', 'gender, job, age, signs',
#        'gender, job, age, city, signs'], dtype=object)

# %%
distinction = pd.DataFrame(np.array([original,o1,o2]).T,columns = ["Original","Out 1","Out 2"])
distinction
# Out:
#                             label Original    Out 1 Out 2
# 0                            city      0.2  0.20661   0.1
# 1                             job      0.7  0.20661   0.2
# 2                          gender      0.8  0.20661   0.2
# 3                             age      1.2  0.30992   0.3
# 4                           signs      3.8  0.30992   0.3
# 5                       job, city      1.4  0.41322   0.2
# 6                    gender, city      1.6  0.41322   0.2
# 7                       age, city      2.4  0.41322   0.3
# 8                     city, signs      5.6  0.61983   0.3
# 9                     gender, job      7.6  0.61983   0.4
# 10                       job, age      8.4  0.61983   0.6
# 11                    gender, age      9.6  0.61983   0.6
# 12                     job, signs       26  0.61983   0.6
# 13                  gender, signs     29.3  0.61983   0.6
# 14                     age, signs     41.3  0.92975   0.9
# 15              gender, job, city     11.2  0.82645   0.4
# 16                 job, age, city     16.8  1.23967   0.6
# 17              gender, age, city     19.2  1.23967   0.6
# 18               job, city, signs     45.1  1.23967   0.6
# 19            gender, city, signs       48  1.23967   0.6
# 20               age, city, signs     51.4  1.23967   0.9
# 21               gender, job, age     62.1  1.23967   1.2
# 22             gender, job, signs     79.3   1.8595   1.2
# 23                job, age, signs     86.4   1.8595   1.8
# 24             gender, age, signs     87.5   1.8595   1.8
# 25         gender, job, age, city     69.5  2.47934   1.2
# 26       gender, job, city, signs     88.8  2.47934   1.2
# 27          job, age, city, signs     92.5  3.71901   1.8
# 28       gender, age, city, signs       95  3.71901   1.8
# 29        gender, job, age, signs     97.8  3.71901   3.6
# 30  gender, job, age, city, signs     99.4  7.02479   3.6

# %%
distinction.plot.area(stacked=False,figsize=(10,10),label="label")
plt.title("Distinction")
plt.xticks([i for i in range(31)],pd.read_csv("out2_sep.csv")["Quasi-identifier"].values.tolist(), rotation=90)
plt.show()

# %%
supression = pd.read_csv("out_1.csv")["gender"]
len(supression[supression == "*"])
# Out:
# 32
